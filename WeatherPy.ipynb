# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# weather_api_key

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alice springs
# Processing Record 2 of Set 1 | zavoronezhskoye
# Processing Record 3 of Set 1 | saurimo
# Processing Record 4 of Set 1 | portland
# Processing Record 5 of Set 1 | minas de marcona
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | fale old settlement
# Processing Record 8 of Set 1 | ust-nera
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | utrik
# Processing Record 11 of Set 1 | khanbari
# Processing Record 12 of Set 1 | semenivka
# Processing Record 13 of Set 1 | mitu
# Processing Record 14 of Set 1 | borujen
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | salacgriva
# Processing Record 17 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | viedma
# Processing Record 21 of Set 1 | puerto natales
# Processing Record 22 of Set 1 | margaret river
# Processing Record 23 of Set 1 | la'ie
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | usakos
# Processing Record 26 of Set 1 | porto seguro
# Processing Record 27 of Set 1 | invercargill
# Processing Record 28 of Set 1 | vadso
# Processing Record 29 of Set 1 | olonkinbyen
# Processing Record 30 of Set 1 | anastacio
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | navia
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | ak-suu
# Processing Record 37 of Set 1 | sinfra
# Processing Record 38 of Set 1 | mejit
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | waitangi
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | hadibu
# Processing Record 44 of Set 1 | la tuque
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 1 | choyr
# Processing Record 48 of Set 1 | tazovsky
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | lebu
# Processing Record 0 of Set 2 | aykhal
# Processing Record 1 of Set 2 | anshun
# Processing Record 2 of Set 2 | klyuchi
# Processing Record 3 of Set 2 | malanje
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | la sarre
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | gemena
# Processing Record 8 of Set 2 | muslyumovo
# Processing Record 9 of Set 2 | sarikei
# Processing Record 10 of Set 2 | iskateley
# Processing Record 11 of Set 2 | isafjordur
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | bijie
# Processing Record 17 of Set 2 | ceeldheer
# Processing Record 18 of Set 2 | north platte
# Processing Record 19 of Set 2 | hawaiian paradise park
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | xique xique
# Processing Record 22 of Set 2 | bodo
# Processing Record 23 of Set 2 | along
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | nago
# Processing Record 26 of Set 2 | nieuw amsterdam
# Processing Record 27 of Set 2 | bonthe
# Processing Record 28 of Set 2 | kapa'a
# Processing Record 29 of Set 2 | tolanaro
# Processing Record 30 of Set 2 | mount pearl
# Processing Record 31 of Set 2 | nova sintra
# Processing Record 32 of Set 2 | martuk
# Processing Record 33 of Set 2 | kaa-khem
# Processing Record 34 of Set 2 | enewetak
# Processing Record 35 of Set 2 | kismayo
# Processing Record 36 of Set 2 | howrah
# Processing Record 37 of Set 2 | brookings
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | ghat
# Processing Record 40 of Set 2 | kharp
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | college
# Processing Record 43 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 44 of Set 2 | bubaque
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | north ward
# Processing Record 47 of Set 2 | vorgashor
# Processing Record 48 of Set 2 | kourou
# Processing Record 49 of Set 2 | blackmans bay
# Processing Record 0 of Set 3 | east london
# Processing Record 1 of Set 3 | lihue
# Processing Record 2 of Set 3 | altar
# Processing Record 3 of Set 3 | jinchang
# Processing Record 4 of Set 3 | atafu village
# Processing Record 5 of Set 3 | nantucket
# Processing Record 6 of Set 3 | xapuri
# Processing Record 7 of Set 3 | machico
# Processing Record 8 of Set 3 | fada
# Processing Record 9 of Set 3 | ushuaia
# Processing Record 10 of Set 3 | san carlos
# Processing Record 11 of Set 3 | kande
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | gizo
# Processing Record 14 of Set 3 | badger
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | port said
# Processing Record 17 of Set 3 | diffa
# Processing Record 18 of Set 3 | monrovia
# Processing Record 19 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 3 | la gi
# Processing Record 21 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 22 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | staryye ozinki
# Processing Record 25 of Set 3 | kiunga
# Processing Record 26 of Set 3 | stanley
# Processing Record 27 of Set 3 | bhuj
# Processing Record 28 of Set 3 | port mathurin
# Processing Record 29 of Set 3 | la ronge
# Processing Record 30 of Set 3 | polyarnyy
# Processing Record 31 of Set 3 | al bardiyah
# Processing Record 32 of Set 3 | maintirano
# Processing Record 33 of Set 3 | ciudad bolivar
# Processing Record 34 of Set 3 | ola
# Processing Record 35 of Set 3 | edinburgh of the seven seas
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | benjamin hill
# Processing Record 38 of Set 3 | gisborne
# Processing Record 39 of Set 3 | nchelenge
# Processing Record 40 of Set 3 | rio bueno
# Processing Record 41 of Set 3 | murun-kuren
# Processing Record 42 of Set 3 | nemuro
# Processing Record 43 of Set 3 | valley city
# Processing Record 44 of Set 3 | la passe
# Processing Record 45 of Set 3 | mahina
# Processing Record 46 of Set 3 | constantia
# Processing Record 47 of Set 3 | el haouaria
# Processing Record 48 of Set 3 | boende
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 0 of Set 4 | redwood falls
# Processing Record 1 of Set 4 | mount isa
# Processing Record 2 of Set 4 | port sudan
# Processing Record 3 of Set 4 | yuzhno-kurilsk
# Processing Record 4 of Set 4 | pacific grove
# Processing Record 5 of Set 4 | launceston
# Processing Record 6 of Set 4 | tsiombe
# Processing Record 7 of Set 4 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 8 of Set 4 | cururupu
# Processing Record 9 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 4 | montagu
# Processing Record 11 of Set 4 | lucapa
# Processing Record 12 of Set 4 | ramachandrapuram
# Processing Record 13 of Set 4 | faya-largeau
# Processing Record 14 of Set 4 | malango
# Processing Record 15 of Set 4 | clovis
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | taoudenni
# Processing Record 18 of Set 4 | diu
# Processing Record 19 of Set 4 | ngorongoro
# Processing Record 20 of Set 4 | wailua homesteads
# Processing Record 21 of Set 4 | plettenberg bay
# Processing Record 22 of Set 4 | kolokani
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | aasiaat
# Processing Record 25 of Set 4 | newman
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 4 | alpnach
# Processing Record 29 of Set 4 | nuuk
# Processing Record 30 of Set 4 | tzaneen
# Processing Record 31 of Set 4 | cannonvale
# Processing Record 32 of Set 4 | afaahiti
# Processing Record 33 of Set 4 | usak
# Processing Record 34 of Set 4 | naze
# Processing Record 35 of Set 4 | igarka
# Processing Record 36 of Set 4 | tofol
# Processing Record 37 of Set 4 | northam
# Processing Record 38 of Set 4 | bikenibeu village
# Processing Record 39 of Set 4 | olovyannaya
# Processing Record 40 of Set 4 | moldava nad bodvou
# Processing Record 41 of Set 4 | nkurenkuru
# City not found. Skipping...
# Processing Record 42 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 43 of Set 4 | de aar
# Processing Record 44 of Set 4 | anamosa
# Processing Record 45 of Set 4 | newark
# Processing Record 46 of Set 4 | anatuya
# Processing Record 47 of Set 4 | gadzhiyevo
# Processing Record 48 of Set 4 | dudinka
# Processing Record 49 of Set 4 | bunbury
# Processing Record 0 of Set 5 | dubbo
# Processing Record 1 of Set 5 | al awjam
# Processing Record 2 of Set 5 | baiao
# Processing Record 3 of Set 5 | sisimiut
# Processing Record 4 of Set 5 | khandyga
# Processing Record 5 of Set 5 | sao tome
# Processing Record 6 of Set 5 | magadan
# Processing Record 7 of Set 5 | vize
# Processing Record 8 of Set 5 | bethanie
# Processing Record 9 of Set 5 | coahuayana de hidalgo
# Processing Record 10 of Set 5 | hammerfest
# Processing Record 11 of Set 5 | daru
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | meadow lakes
# Processing Record 14 of Set 5 | mana
# Processing Record 15 of Set 5 | ellsworth
# Processing Record 16 of Set 5 | nar'yan-mar
# Processing Record 17 of Set 5 | shatsk
# Processing Record 18 of Set 5 | duba
# Processing Record 19 of Set 5 | toliara
# Processing Record 20 of Set 5 | wanganui
# Processing Record 21 of Set 5 | labrador city
# Processing Record 22 of Set 5 | leshan
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | magdagachi
# Processing Record 25 of Set 5 | divo
# Processing Record 26 of Set 5 | santa ana
# Processing Record 27 of Set 5 | misratah
# Processing Record 28 of Set 5 | castillos
# Processing Record 29 of Set 5 | shamkhor
# Processing Record 30 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 31 of Set 5 | okha
# Processing Record 32 of Set 5 | fort bragg
# Processing Record 33 of Set 5 | berriozar
# Processing Record 34 of Set 5 | oranjestad
# Processing Record 35 of Set 5 | timimoun
# Processing Record 36 of Set 5 | codrington
# Processing Record 37 of Set 5 | weno
# Processing Record 38 of Set 5 | xai-xai
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | sinop
# Processing Record 41 of Set 5 | san antonio de pale
# Processing Record 42 of Set 5 | monchegorsk
# Processing Record 43 of Set 5 | uturoa
# Processing Record 44 of Set 5 | kemin
# Processing Record 45 of Set 5 | bechar
# Processing Record 46 of Set 5 | urengoy
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | mukah
# City not found. Skipping...
# Processing Record 0 of Set 6 | pagar alam
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | christchurch
# Processing Record 3 of Set 6 | nong phai
# Processing Record 4 of Set 6 | kyaikkami
# Processing Record 5 of Set 6 | montevideo
# Processing Record 6 of Set 6 | namtsy
# Processing Record 7 of Set 6 | urussu
# Processing Record 8 of Set 6 | luanda
# Processing Record 9 of Set 6 | olevano sul tusciano
# Processing Record 10 of Set 6 | st. john's
# Processing Record 11 of Set 6 | leu
# Processing Record 12 of Set 6 | horki
# Processing Record 13 of Set 6 | strathalbyn
# Processing Record 14 of Set 6 | cidade velha
# Processing Record 15 of Set 6 | flying fish cove
# Processing Record 16 of Set 6 | rio grande
# Processing Record 17 of Set 6 | gostyn
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | west island
# Processing Record 20 of Set 6 | nizhnyaya salda
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | tamanrasset
# Processing Record 23 of Set 6 | huarmey
# Processing Record 24 of Set 6 | beau vallon
# Processing Record 25 of Set 6 | amarante do maranhao
# Processing Record 26 of Set 6 | turabah
# Processing Record 27 of Set 6 | wenzhou
# Processing Record 28 of Set 6 | embarcacion
# Processing Record 29 of Set 6 | tralee
# Processing Record 30 of Set 6 | gamboma
# Processing Record 31 of Set 6 | san felice circeo
# Processing Record 32 of Set 6 | molina
# Processing Record 33 of Set 6 | beyneu
# Processing Record 34 of Set 6 | cairns city
# City not found. Skipping...
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | taro
# Processing Record 37 of Set 6 | luena
# Processing Record 38 of Set 6 | dongola
# Processing Record 39 of Set 6 | colonia
# Processing Record 40 of Set 6 | bembereke
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | rundu
# Processing Record 43 of Set 6 | sitka
# Processing Record 44 of Set 6 | sereflikochisar
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | udachny
# Processing Record 47 of Set 6 | wau
# Processing Record 48 of Set 6 | essaouira
# Processing Record 49 of Set 6 | broome
# Processing Record 0 of Set 7 | cabral
# Processing Record 1 of Set 7 | pasni
# Processing Record 2 of Set 7 | ust'-kut
# Processing Record 3 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 4 of Set 7 | manuguru
# Processing Record 5 of Set 7 | callao
# Processing Record 6 of Set 7 | avarua
# Processing Record 7 of Set 7 | palo santo
# Processing Record 8 of Set 7 | ouesso
# Processing Record 9 of Set 7 | maues
# Processing Record 10 of Set 7 | kalabo
# Processing Record 11 of Set 7 | keflavik
# Processing Record 12 of Set 7 | camocim
# Processing Record 13 of Set 7 | queenstown
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | fort st. john
# Processing Record 16 of Set 7 | acarau
# Processing Record 17 of Set 7 | mhamid
# Processing Record 18 of Set 7 | rumbek
# Processing Record 19 of Set 7 | carnarvon
# Processing Record 20 of Set 7 | usinsk
# Processing Record 21 of Set 7 | south hedland
# Processing Record 22 of Set 7 | turpan
# Processing Record 23 of Set 7 | bojnurd
# Processing Record 24 of Set 7 | ghadamis
# Processing Record 25 of Set 7 | san ciro de acosta
# Processing Record 26 of Set 7 | kokopo
# Processing Record 27 of Set 7 | neijiang
# Processing Record 28 of Set 7 | al burayqah
# Processing Record 29 of Set 7 | ust'-ilimsk
# Processing Record 30 of Set 7 | ciudad tula
# Processing Record 31 of Set 7 | beruniy
# Processing Record 32 of Set 7 | pontes e lacerda
# Processing Record 33 of Set 7 | cuyo
# Processing Record 34 of Set 7 | tazacorte
# Processing Record 35 of Set 7 | penzance
# Processing Record 36 of Set 7 | savanna-la-mar
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | anadyr
# Processing Record 39 of Set 7 | saint saviour
# City not found. Skipping...
# Processing Record 40 of Set 7 | kurortnyy
# City not found. Skipping...
# Processing Record 41 of Set 7 | ta`u
# Processing Record 42 of Set 7 | san andres
# Processing Record 43 of Set 7 | fort mcmurray
# Processing Record 44 of Set 7 | suklayin
# Processing Record 45 of Set 7 | winder
# Processing Record 46 of Set 7 | blenheim
# Processing Record 47 of Set 7 | vila franca do campo
# Processing Record 48 of Set 7 | beichengqu
# Processing Record 49 of Set 7 | vilyuchinsk
# Processing Record 0 of Set 8 | al mithnab
# City not found. Skipping...
# Processing Record 1 of Set 8 | kayyerkan
# Processing Record 2 of Set 8 | shingu
# Processing Record 3 of Set 8 | pasuquin
# Processing Record 4 of Set 8 | saipan
# Processing Record 5 of Set 8 | jwaneng
# Processing Record 6 of Set 8 | kirakira
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | taksimo
# Processing Record 9 of Set 8 | awjilah
# Processing Record 10 of Set 8 | javea
# Processing Record 11 of Set 8 | kapuskasing
# Processing Record 12 of Set 8 | el jadid
# Processing Record 13 of Set 8 | bereznik
# Processing Record 14 of Set 8 | mandalgovi
# Processing Record 15 of Set 8 | seabra
# Processing Record 16 of Set 8 | usogorsk
# Processing Record 17 of Set 8 | island harbour
# Processing Record 18 of Set 8 | vizinga
# Processing Record 19 of Set 8 | villa regina
# Processing Record 20 of Set 8 | atamyrat
# Processing Record 21 of Set 8 | maragogi
# Processing Record 22 of Set 8 | hithadhoo
# Processing Record 23 of Set 8 | palikir - national government center
# Processing Record 24 of Set 8 | ketchikan
# Processing Record 25 of Set 8 | garoua boulai
# Processing Record 26 of Set 8 | taltal
# Processing Record 27 of Set 8 | ha giang
# Processing Record 28 of Set 8 | abbeville
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | dawukou
# Processing Record 31 of Set 8 | kroonstad
# Processing Record 32 of Set 8 | kingston
# Processing Record 33 of Set 8 | eisen
# Processing Record 34 of Set 8 | pathein
# Processing Record 35 of Set 8 | sechura
# Processing Record 36 of Set 8 | carutapera
# Processing Record 37 of Set 8 | lata
# Processing Record 38 of Set 8 | gudalur
# Processing Record 39 of Set 8 | onega
# Processing Record 40 of Set 8 | quepos
# Processing Record 41 of Set 8 | kavaratti
# Processing Record 42 of Set 8 | fortaleza
# Processing Record 43 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 8 | jurmala
# Processing Record 45 of Set 8 | kidal
# Processing Record 46 of Set 8 | taitung city
# Processing Record 47 of Set 8 | lazaro cardenas
# Processing Record 48 of Set 8 | ebaye
# Processing Record 49 of Set 8 | malvan
# Processing Record 0 of Set 9 | puerto ayacucho
# Processing Record 1 of Set 9 | kristiansund
# Processing Record 2 of Set 9 | haiku-pauwela
# Processing Record 3 of Set 9 | villa gesell
# Processing Record 4 of Set 9 | hami
# Processing Record 5 of Set 9 | szentlorinc
# Processing Record 6 of Set 9 | antsiranana
# Processing Record 7 of Set 9 | qarah
# Processing Record 8 of Set 9 | page
# Processing Record 9 of Set 9 | stornoway
# Processing Record 10 of Set 9 | medvezh'yegorsk
# Processing Record 11 of Set 9 | san luis de la loma
# Processing Record 12 of Set 9 | orchomenos
# Processing Record 13 of Set 9 | gamba
# Processing Record 14 of Set 9 | khabary
# Processing Record 15 of Set 9 | sal rei
# Processing Record 16 of Set 9 | berrouaghia
# Processing Record 17 of Set 9 | goure
# Processing Record 18 of Set 9 | north bend
# Processing Record 19 of Set 9 | amga
# Processing Record 20 of Set 9 | ebon
# Processing Record 21 of Set 9 | mbandaka
# Processing Record 22 of Set 9 | happy valley-goose bay
# Processing Record 23 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 9 | caleta olivia
# Processing Record 25 of Set 9 | luis correia
# Processing Record 26 of Set 9 | menongue
# Processing Record 27 of Set 9 | port lincoln
# Processing Record 28 of Set 9 | charters towers
# Processing Record 29 of Set 9 | pokhara
# Processing Record 30 of Set 9 | novobataysk
# Processing Record 31 of Set 9 | porto novo
# Processing Record 32 of Set 9 | ust-tsilma
# Processing Record 33 of Set 9 | cabedelo
# Processing Record 34 of Set 9 | port macquarie
# Processing Record 35 of Set 9 | bom jesus
# Processing Record 36 of Set 9 | orosei
# Processing Record 37 of Set 9 | hilo
# Processing Record 38 of Set 9 | lobujya
# Processing Record 39 of Set 9 | juba
# Processing Record 40 of Set 9 | bamboo flat
# Processing Record 41 of Set 9 | paracatu
# Processing Record 42 of Set 9 | sokolow podlaski
# Processing Record 43 of Set 9 | krasnogvargeisky
# City not found. Skipping...
# Processing Record 44 of Set 9 | portage la prairie
# Processing Record 45 of Set 9 | sao felix do xingu
# Processing Record 46 of Set 9 | el nido
# Processing Record 47 of Set 9 | kone
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | manokwari
# Processing Record 0 of Set 10 | cold springs
# Processing Record 1 of Set 10 | remire-montjoly
# Processing Record 2 of Set 10 | 'ain el hadjel
# City not found. Skipping...
# Processing Record 3 of Set 10 | phanom thuan
# Processing Record 4 of Set 10 | emerald
# Processing Record 5 of Set 10 | bikaner
# Processing Record 6 of Set 10 | jalpan
# Processing Record 7 of Set 10 | betio village
# Processing Record 8 of Set 10 | belyy yar
# Processing Record 9 of Set 10 | yung shue wan
# Processing Record 10 of Set 10 | port lavaca
# Processing Record 11 of Set 10 | mamboma
# Processing Record 12 of Set 10 | nawada
# Processing Record 13 of Set 10 | cooma
# Processing Record 14 of Set 10 | mpika
# Processing Record 15 of Set 10 | rosso
# Processing Record 16 of Set 10 | mildenhall
# Processing Record 17 of Set 10 | dalbandin
# Processing Record 18 of Set 10 | kimbe
# Processing Record 19 of Set 10 | kerikeri
# Processing Record 20 of Set 10 | nishinoomote
# Processing Record 21 of Set 10 | nora
# Processing Record 22 of Set 10 | arraial do cabo
# Processing Record 23 of Set 10 | kirensk
# Processing Record 24 of Set 10 | kattivakkam
# Processing Record 25 of Set 10 | kailua-kona
# Processing Record 26 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 10 | kalmunai
# Processing Record 28 of Set 10 | camana
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | tarauaca
# Processing Record 31 of Set 10 | sao jose da coroa grande
# Processing Record 32 of Set 10 | toamasina
# Processing Record 33 of Set 10 | macas
# Processing Record 34 of Set 10 | midvagur
# Processing Record 35 of Set 10 | dunedin
# Processing Record 36 of Set 10 | sake
# Processing Record 37 of Set 10 | lagos
# Processing Record 38 of Set 10 | chonchi
# Processing Record 39 of Set 10 | la dorada
# Processing Record 40 of Set 10 | barcelos
# Processing Record 41 of Set 10 | shyroke
# Processing Record 42 of Set 10 | tionk essil
# Processing Record 43 of Set 10 | banda aceh
# Processing Record 44 of Set 10 | mersrags
# Processing Record 45 of Set 10 | tual
# Processing Record 46 of Set 10 | sahab
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | alenquer
# Processing Record 49 of Set 10 | port blair
# Processing Record 0 of Set 11 | ibateguara
# Processing Record 1 of Set 11 | nadym
# Processing Record 2 of Set 11 | chunskiy
# Processing Record 3 of Set 11 | lensk
# Processing Record 4 of Set 11 | cabo san lucas
# Processing Record 5 of Set 11 | guiuan
# Processing Record 6 of Set 11 | ts'nori
# Processing Record 7 of Set 11 | smithers
# Processing Record 8 of Set 11 | nikolayevsk-on-amure
# Processing Record 9 of Set 11 | borba
# Processing Record 10 of Set 11 | tovuz
# Processing Record 11 of Set 11 | bosobolo
# Processing Record 12 of Set 11 | hirara
# Processing Record 13 of Set 11 | pervomayskoye
# Processing Record 14 of Set 11 | say
# Processing Record 15 of Set 11 | chui
# Processing Record 16 of Set 11 | la foa
# Processing Record 17 of Set 11 | aioun
# Processing Record 18 of Set 11 | paka
# Processing Record 19 of Set 11 | hotan
# Processing Record 20 of Set 11 | tocopilla
# Processing Record 21 of Set 11 | jatibonico
# Processing Record 22 of Set 11 | nandu
# Processing Record 23 of Set 11 | hatta
# Processing Record 24 of Set 11 | duncan town
# City not found. Skipping...
# Processing Record 25 of Set 11 | san luis del palmar
# Processing Record 26 of Set 11 | aripuana
# Processing Record 27 of Set 11 | manaure
# Processing Record 28 of Set 11 | woolgoolga
# Processing Record 29 of Set 11 | vernon
# Processing Record 30 of Set 11 | coquimbo
# Processing Record 31 of Set 11 | macau
# Processing Record 32 of Set 11 | renqiu
# Processing Record 33 of Set 11 | levuka
# Processing Record 34 of Set 11 | butner
# Processing Record 35 of Set 11 | tromso
# Processing Record 36 of Set 11 | sarkand
# Processing Record 37 of Set 11 | mau
# Processing Record 38 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 39 of Set 11 | barpeta
# Processing Record 40 of Set 11 | kerteminde
# Processing Record 41 of Set 11 | atherton
# Processing Record 42 of Set 11 | dien bien phu
# Processing Record 43 of Set 11 | beledweyne
# Processing Record 44 of Set 11 | kanker
# Processing Record 45 of Set 11 | zheleznogorsk
# Processing Record 46 of Set 11 | rome
# Processing Record 47 of Set 11 | greenville
# Processing Record 48 of Set 11 | cockburn town
# Processing Record 49 of Set 11 | camapua
# Processing Record 0 of Set 12 | semera
# Processing Record 1 of Set 12 | chernyshevskiy
# Processing Record 2 of Set 12 | sidi ifni
# Processing Record 3 of Set 12 | conduaga
# Processing Record 4 of Set 12 | inhambane
# Processing Record 5 of Set 12 | sur
# Processing Record 6 of Set 12 | alo
# Processing Record 7 of Set 12 | choibalsan
# Processing Record 8 of Set 12 | ciudad del carmen
# Processing Record 9 of Set 12 | shimoda
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | sinabang
# Processing Record 12 of Set 12 | manaure balcon del cesar
# Processing Record 13 of Set 12 | sokoni
# Processing Record 14 of Set 12 | singkil
# Processing Record 15 of Set 12 | romblon
# Processing Record 16 of Set 12 | ixtapa
# Processing Record 17 of Set 12 | paris
# Processing Record 18 of Set 12 | victoria falls
# Processing Record 19 of Set 12 | adamovka
# Processing Record 20 of Set 12 | kalnibolotskaya
# Processing Record 21 of Set 12 | bardai
# Processing Record 22 of Set 12 | pailon
# Processing Record 23 of Set 12 | miyanoura
# City not found. Skipping...
# Processing Record 24 of Set 12 | banjarmasin
# Processing Record 25 of Set 12 | saint joseph
# Processing Record 26 of Set 12 | zhangjiajie
# Processing Record 27 of Set 12 | yaren
# Processing Record 28 of Set 12 | bulnes
# Processing Record 29 of Set 12 | saudarkrokur
# Processing Record 30 of Set 12 | ha'il
# Processing Record 31 of Set 12 | mossel bay
# Processing Record 32 of Set 12 | berdigestyakh
# Processing Record 33 of Set 12 | fonadhoo
# City not found. Skipping...
# Processing Record 34 of Set 12 | susuman
# Processing Record 35 of Set 12 | taungoo
# Processing Record 36 of Set 12 | bafq
# Processing Record 37 of Set 12 | st. catharines
# Processing Record 38 of Set 12 | villamontes
# Processing Record 39 of Set 12 | severo-yeniseyskiy
# Processing Record 40 of Set 12 | geroskipou
# City not found. Skipping...
# Processing Record 41 of Set 12 | pekan
# Processing Record 42 of Set 12 | igrim
# Processing Record 43 of Set 12 | nguigmi
# Processing Record 44 of Set 12 | praia da vitoria
# Processing Record 45 of Set 12 | barra
# Processing Record 46 of Set 12 | qingdao
# Processing Record 47 of Set 12 | labuan lombok
# City not found. Skipping...
# Processing Record 48 of Set 12 | kilindoni
# Processing Record 49 of Set 12 | jijiga
# Processing Record 0 of Set 13 | le vauclin
# Processing Record 1 of Set 13 | genhe
# Processing Record 2 of Set 13 | senhor do bonfim
# Processing Record 3 of Set 13 | linxia chengguanzhen
# Processing Record 4 of Set 13 | anna
# Processing Record 5 of Set 13 | salmon arm
# Processing Record 6 of Set 13 | lauro de freitas
# Processing Record 7 of Set 13 | freetown
# Processing Record 8 of Set 13 | port-gentil
# Processing Record 9 of Set 13 | arkhangel'sk
# Processing Record 10 of Set 13 | sohbatpur
# Processing Record 11 of Set 13 | wynyard
# Processing Record 12 of Set 13 | ash shafa
# City not found. Skipping...
# Processing Record 13 of Set 13 | san borja
# Processing Record 14 of Set 13 | cotonou
# Processing Record 15 of Set 13 | selty
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          587
# Lat           587
# Lng           587
# Max Temp      587
# Humidity      587
# Cloudiness    587
# Wind Speed    587
# Country       587
# Date          587
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     alice springs -23.7000  133.8833     35.75        13          91
# 1   zavoronezhskoye  52.8801   40.5526     12.88        88         100
# 2           saurimo  -9.6608   20.3916     32.21        36          88
# 3          portland  45.5234 -122.6762     13.12        84          40
# 4  minas de marcona -15.2119  -75.1103     13.37        92          88
#
#    Wind Speed Country        Date
# 0        7.20      AU  1696235273
# 1        3.13      RU  1696235520
# 2        0.99      AO  1696235520
# 3        0.45      US  1696234955
# 4        4.09      PE  1696235520

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           alice springs -23.7000  133.8833     35.75        13          91
# 1         zavoronezhskoye  52.8801   40.5526     12.88        88         100
# 2                 saurimo  -9.6608   20.3916     32.21        36          88
# 3                portland  45.5234 -122.6762     13.12        84          40
# 4        minas de marcona -15.2119  -75.1103     13.37        92          88
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      AU  1696235273
# 1              3.13      RU  1696235520
# 2              0.99      AO  1696235520
# 3              0.45      US  1696234955
# 4              4.09      PE  1696235520

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
city_data_df.head(2)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          alice springs -23.7000  133.8833     35.75        13          91
# 1        zavoronezhskoye  52.8801   40.5526     12.88        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      AU  1696235273
# 1              3.13      RU  1696235520

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title("City Max Latitude vs. Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df["Lat"]
humidity = city_data_df["Humidity"]

# Incorporate the other graph properties
plt.scatter(latitude, humidity, edgecolors = 'black', alpha = 0.7)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (%)")

# plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]

# Incorporate the other graph properties
plt.scatter(latitude, cloudiness, edgecolors = 'black', alpha = 0.7)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs. Cloudiness")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df['Wind Speed']
plt.scatter(latitude, wind_speed, edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        zavoronezhskoye  52.8801   40.5526     12.88        88         100
# 3               portland  45.5234 -122.6762     13.12        84          40
# 5                 lompoc  34.6391 -120.4579     12.74        87           0
# 7               ust-nera  64.5667  143.2000      1.79        56          22
# 9                  utrik  11.2278  169.8474     28.43        80          80
#
#          Wind Speed Country        Date
# City_ID
# 1              3.13      RU  1696235520
# 3              0.45      US  1696234955
# 5              2.06      US  1696235484
# 7              2.68      RU  1696235520
# 9              4.86      MH  1696235520

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0              alice springs -23.7000  133.8833     35.75        13
# 2                    saurimo  -9.6608   20.3916     32.21        36
# 4           minas de marcona -15.2119  -75.1103     13.37        92
# 6        fale old settlement  -9.3852 -171.2468     27.56        80
# 8          port-aux-francais -49.3500   70.2167      0.55        67
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                91        7.20      AU  1696235273
# 2                88        0.99      AO  1696235520
# 4                88        4.09      PE  1696235520
# 6               100        2.92      TK  1696235520
# 8                44       18.57      TF  1696235520

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
north_lat = northern_hemi_df["Lat"]
north_temp = northern_hemi_df["Max Temp"]
slope = linregress(north_lat, north_temp)
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_temp)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot
plt.scatter(north_lat, north_temp, edgecolors="black", alpha=.8)
plt.plot(north_lat, regress_values, "-r")
plt.annotate(line_eq,(10,2),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title ("Temperature vs. Latitude Linear Regression Plot (Northern Hemisphere)")


print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.8506312534379142

# %% [markdown]
# **Discussion about the linear relationship:** Temperature vs. Latitude Linear Regression Plot (Northern Hemisphere)
# - There seems to be a correlation Between the temperature and latitude without too many outliers
# - As the latitude increases the temperature decreases displaying a decline trend

# %%
# Linear regression on Southern Hemisphere
south_lat = southern_hemi_df["Lat"]
south_temp = southern_hemi_df["Max Temp"]
slope = linregress(south_lat, south_temp)
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_temp)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot
plt.scatter(south_lat, south_temp, edgecolors ="black", alpha=.8)
plt.plot(south_lat, regress_values, "-r")
plt.annotate(line_eq,(-25,5),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title ("Temperature vs. Latitude Linear Regression Plot (Southern Hemisphere)")

print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.7231774597253154

# %% [markdown]
# **Discussion about the linear relationship:** Temperature vs. Latitude Linear Regression Plot (Southern Hemisphere)
# - There seems to be a correlation between temperature and latitude
# - As the latitude increases, so does the temperature within the southern hemisphere
# - This points to an incline trend as latitude increases opposite to the northern hemisphere's result

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# we have north_lat for x values
north_hum = northern_hemi_df['Humidity']

slope = linregress(north_lat, north_hum)
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_hum)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build Scatter plot
plt.scatter(north_lat, north_hum, edgecolors="black", alpha=.8)
plt.plot(north_lat, regress_values, "-r")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title ("Humidity vs. Latitude Linear Regression Plot (Northern Hemisphere)")


print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.07398163084263469

# %% [markdown]
# **Discussion about the linear relationship:** Humidity vs. Latitude Linear Regression Plot (Northern Hemisphere)
# - There seems to be a slight correlation leading into an incline trend within humidity and latitude
# - However I do not think that this correlation would lead to a proper analysis

# %%
# Southern Hemisphere
# We have south_lat for the x values
south_hum = southern_hemi_df["Humidity"]
slope = linregress(south_lat, south_hum)
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_hum)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot
plt.scatter(south_lat, south_hum, edgecolors ="black", alpha=.8)
plt.plot(south_lat, regress_values, "-r")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title ("Humidity vs. Latitude Linear Regression Plot (Southern Hemisphere)")

print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.06818556999196451

# %% [markdown]
# **Discussion about the linear relationship:** Humidity vs. Latitude Linear Regression Plot (Southern Hemisphere)
# - There seems to be a slight correlation leading into an incline trend within humidity and latitude
# - However I do not think that this correlation would lead to a proper analysis similar to the northern hemisphere
# - I can conclude that both hemisphere have the similar trends in humidity and latitude

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# we have north_lat for x values
north_cloud = northern_hemi_df['Cloudiness']

slope = linregress(north_lat, north_cloud)
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_cloud)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build Scatter plot
plt.scatter(north_lat, north_cloud, edgecolors="black", alpha=.8)
plt.plot(north_lat, regress_values, "-r")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title ("Cloudiness vs Latitude (Northern Hemisphere)")


print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.09761654941436886

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness vs Latitude (Northern Hemisphere)
# - There seems to be a slight correlation leading into an incline trend within Cloudiness and latitude
# - However I do not think that this correlation would lead to a proper analysis since there seems to be too many variables

# %%
# Southern Hemisphere
# We have south_lat for the x values
south_cloud = southern_hemi_df["Cloudiness"]
slope = linregress(south_lat, south_cloud)
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_cloud)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot
plt.scatter(south_lat, south_cloud, edgecolors ="black", alpha=.8)
plt.plot(south_lat, regress_values, "-r")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title ("Cloudiness vs Latitude (Southern Hemisphere)")

print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.18533903541865426

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness vs Latitude (Southern Hemisphere)
# - There seems to be a slight correlation leading into an incline trend within Cloudiness and latitude
# - However I do not think that this correlation would lead to a proper analysis similar to the northern hemisphere's result
# - I can conclude that both hemisphere have the similar trends in humidity and latitude

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# we have north_lat for x values
north_wind = northern_hemi_df['Wind Speed']

slope = linregress(north_lat, north_wind)
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_wind)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build Scatter plot
plt.scatter(north_lat, north_wind, edgecolors="black", alpha=.8)
plt.plot(north_lat, regress_values, "-r")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title ("Wind Speed vs. Latitude Linear Regression Plot (Northern Hemisphere)")


print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.11480288226580264

# %% [markdown]
# **Discussion about the linear relationship:** Wind Speed vs. Latitude Linear Regression Plot (Northern Hemisphere)
# - There seems to be a correlation leading into an decline trend with Wind Speed and latitude
# - The wind speed seems to stay stagnant despite the increase in latitude

# %%
# Southern Hemisphere
# We have south_lat for the x values
south_wind = southern_hemi_df["Wind Speed"]
slope = linregress(south_lat,south_wind)
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_wind)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot
plt.scatter(south_lat, south_wind, edgecolors ="black", alpha=.8)
plt.plot(south_lat, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title ("Wind Speed vs. Latitude Linear Regression Plot (Southern Hemisphere)")

print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.1893374822460468

# %% [markdown]
# **Discussion about the linear relationship:** Wind Speed vs. Latitude Linear Regression Plot (Southern Hemisphere)
# - There seems to be a correlation leading into an decline trend with Wind Speed and latitude
# - The wind speed seems to stay stagnant despite the negative latitude

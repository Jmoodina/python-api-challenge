# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Install Packages
# !pip install hvplot geoviews datashader cartopy pyproj
# Out:
# Requirement already satisfied: hvplot in c:\users\sauceyclaps\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: geoviews in c:\users\sauceyclaps\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: datashader in c:\users\sauceyclaps\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: cartopy in c:\users\sauceyclaps\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: pyproj in c:\users\sauceyclaps\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (3.2.1)
# Requirement already satisfied: colorcet>=2 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (1.17.0)
# Requirement already satisfied: pandas in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (1.24.3)
# Requirement already satisfied: packaging in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (23.0)
# Requirement already satisfied: panel>=0.11.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (1.2.1)
# Requirement already satisfied: param>=1.9.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: shapely in c:\users\sauceyclaps\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: xyzservices in c:\users\sauceyclaps\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: dask in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (2023.6.0)
# Requirement already satisfied: datashape in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (0.5.4)
# Requirement already satisfied: numba in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (0.57.0)
# Requirement already satisfied: pillow in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (9.4.0)
# Requirement already satisfied: pyct in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (1.10.1)
# Requirement already satisfied: toolz in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashader) (2023.6.0)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: pyshp>=2.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: certifi in c:\users\sauceyclaps\anaconda3\lib\site-packages (from pyproj) (2023.7.22)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.0.5)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.3.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: markdown in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\sauceyclaps\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.7.1)
# Requirement already satisfied: click>=8.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from dask->datashader) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from dask->datashader) (2023.3.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from dask->datashader) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from dask->datashader) (6.0.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from numba->datashader) (0.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from requests->datashader) (1.26.16)
# Requirement already satisfied: colorama in c:\users\sauceyclaps\anaconda3\lib\site-packages (from click>=8.0->dask->datashader) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.1)
# Requirement already satisfied: six in c:\users\sauceyclaps\anaconda3\lib\site-packages (from multipledispatch>=0.4.7->datashape->datashader) (1.16.0)
# Requirement already satisfied: locket in c:\users\sauceyclaps\anaconda3\lib\site-packages (from partd>=1.2.0->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in c:\users\sauceyclaps\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\sauceyclaps\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sauceyclaps\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head(5)
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0     alice springs -23.7000  133.8833     35.75        13
# 1        1   zavoronezhskoye  52.8801   40.5526     12.88        88
# 2        2           saurimo  -9.6608   20.3916     32.21        36
# 3        3          portland  45.5234 -122.6762     13.12        84
# 4        4  minas de marcona -15.2119  -75.1103     13.37        92
#
#    Cloudiness  Wind Speed Country        Date
# 0          91        7.20      AU  1696235273
# 1         100        3.13      RU  1696235520
# 2          88        0.99      AO  1696235520
# 3          40        0.45      US  1696234955
# 4          88        4.09      PE  1696235520

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Organize point size into humidity and convert astype
humidity = city_data_df["Humidity"].astype(int)

# Configure the map plot
humidity_city = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 700,
    size = "Humidity",
    color="City",
    alpha=0.70
).opts(title="Humidity Geoview Map")


# Display the map
humidity_city
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

#A max temperature lower than 27 degrees but higher than 21
city_data_df = city_data_df.loc[(city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21)]

#Wind speed less than 4.5 m/s
city_data_df = city_data_df.loc[(city_data_df["Wind Speed"] < 5)]

#Zero cloudiness
city_data_df = city_data_df.loc[(city_data_df["Cloudiness"] == 0)]

# Drop results with null values
city_data_df = city_data_df.dropna()

# Display sample data
city_data_df.head()
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 17        17                hermanus -34.4187   19.2345     21.84        48
# 47        47                saldanha -33.0117   17.9442     24.03        36
# 68        68  hawaiian paradise park  19.5933 -154.9731     22.80        95
# 138      138             valley city  46.9233  -98.0032     21.29        64
# 142      142             el haouaria  37.0500   11.0144     25.01        59
#
#      Cloudiness  Wind Speed Country        Date
# 17            0        1.76      ZA  1696235521
# 47            0        0.32      ZA  1696235525
# 68            0        1.54      US  1696235528
# 138           0        4.12      US  1696235536
# 142           0        4.00      TN  1696235536

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

city = city_data_df["City"]
country = city_data_df["Country"]
lat = city_data_df["Lat"]
lng = city_data_df["Lng"]
humidity = city_data_df["Humidity"]

hotel_df = city_data_df[{"City": city,
                        "Country": country,
                        "Lat": lat,
                        "Lng": lng,
                        "Humidity": humidity}]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
# C:\Users\SauceyClaps\AppData\Local\Temp\ipykernel_8284\3768208391.py:9: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   hotel_df = city_data_df[{"City": city,
# C:\Users\SauceyClaps\AppData\Local\Temp\ipykernel_8284\3768208391.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                        City Country      Lat       Lng  Humidity Hotel Name
# 17                 hermanus      ZA -34.4187   19.2345        48
# 47                 saldanha      ZA -33.0117   17.9442        36
# 68   hawaiian paradise park      US  19.5933 -154.9731        95
# 138             valley city      US  46.9233  -98.0032        64
# 142             el haouaria      TN  37.0500   11.0144        59
# 144              bredasdorp      ZA -34.5322   20.0403        38
# 145           redwood falls      US  44.5394  -95.1169        68
# 164         plettenberg bay      ZA -34.0527   23.3716        42
# 170                 alpnach      CH  46.9402    8.2743        72
# 217                misratah      LY  32.3754   15.0925        57
# 222               berriozar      ES  42.8429   -1.6697        66
# 234                  bechar      DZ  31.6167   -2.2167        28
# 247    olevano sul tusciano      IT  40.6572   15.0231        54
# 260             tamanrasset      DZ  22.7850    5.5228        32
# 276                 colonia      DE  50.9333    6.9500        73
# 299              queenstown      ZA -31.8976   26.8753        19
# 309                 bojnurd      IR  37.4747   57.3290        16
# 317                 beruniy      UZ  41.6911   60.7525        27
# 364               kroonstad      ZA -27.6504   27.2349        33
# 386                    hami      CN  42.8000   93.4500        19
# 398             berrouaghia      DZ  36.1352    2.9109        29
# 418                    hilo      US  19.7297 -155.0900        92
# 439             port lavaca      US  28.6150  -96.6261        90
# 454             kailua-kona      US  19.6406 -155.9956        81
# 556              mossel bay      ZA -34.1831   22.1460        52
# 569                 qingdao      CN  36.0986  120.3719        25

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# hermanus - nearest hotel: Aloe guest house
# saldanha - nearest hotel: Hoedjesbaai
# hawaiian paradise park - nearest hotel: No hotel found
# valley city - nearest hotel: AmericInn
# el haouaria - nearest hotel: Villa Zembra Maison d'hôtes
# bredasdorp - nearest hotel: Victoria Hotel
# redwood falls - nearest hotel: Travelodge by Wyndham Redwood Falls
# plettenberg bay - nearest hotel: Milkwood Manor
# alpnach - nearest hotel: Schlüssel
# misratah - nearest hotel: الفندق السياحى
# berriozar - nearest hotel: Hotel Pamplona Plaza
# bechar - nearest hotel: Hôtel Madania
# olevano sul tusciano - nearest hotel: Hotel Cristal
# tamanrasset - nearest hotel: فندق الأمان
# colonia - nearest hotel: Wasserturm Hotel Cologne
# queenstown - nearest hotel: Queens Hotel
# bojnurd - nearest hotel: مرکز آموزشی رفاهی فرهنگیان بجنورد
# beruniy - nearest hotel: Miymanxana
# kroonstad - nearest hotel: No hotel found
# hami - nearest hotel: Хами
# berrouaghia - nearest hotel: Andalous
# hilo - nearest hotel: Dolphin Bay Hotel
# port lavaca - nearest hotel: La Quinta Inn & Suites
# kailua-kona - nearest hotel: Kona Seaside Hotel
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# qingdao - nearest hotel: Le Méridien Qingdao
#                        City Country      Lat       Lng  Humidity  \
# 17                 hermanus      ZA -34.4187   19.2345        48
# 47                 saldanha      ZA -33.0117   17.9442        36
# 68   hawaiian paradise park      US  19.5933 -154.9731        95
# 138             valley city      US  46.9233  -98.0032        64
# 142             el haouaria      TN  37.0500   11.0144        59
# 144              bredasdorp      ZA -34.5322   20.0403        38
# 145           redwood falls      US  44.5394  -95.1169        68
# 164         plettenberg bay      ZA -34.0527   23.3716        42
# 170                 alpnach      CH  46.9402    8.2743        72
# 217                misratah      LY  32.3754   15.0925        57
# 222               berriozar      ES  42.8429   -1.6697        66
# 234                  bechar      DZ  31.6167   -2.2167        28
# 247    olevano sul tusciano      IT  40.6572   15.0231        54
# 260             tamanrasset      DZ  22.7850    5.5228        32
# 276                 colonia      DE  50.9333    6.9500        73
# 299              queenstown      ZA -31.8976   26.8753        19
# 309                 bojnurd      IR  37.4747   57.3290        16
# 317                 beruniy      UZ  41.6911   60.7525        27
# 364               kroonstad      ZA -27.6504   27.2349        33
# 386                    hami      CN  42.8000   93.4500        19
# 398             berrouaghia      DZ  36.1352    2.9109        29
# 418                    hilo      US  19.7297 -155.0900        92
# 439             port lavaca      US  28.6150  -96.6261        90
# 454             kailua-kona      US  19.6406 -155.9956        81
# 556              mossel bay      ZA -34.1831   22.1460        52
# 569                 qingdao      CN  36.0986  120.3719        25
#
#                               Hotel Name
# 17                      Aloe guest house
# 47                           Hoedjesbaai
# 68                        No hotel found
# 138                            AmericInn
# 142          Villa Zembra Maison d'hôtes
# 144                       Victoria Hotel
# 145  Travelodge by Wyndham Redwood Falls
# 164                       Milkwood Manor
# 170                            Schlüssel
# 217                       الفندق السياحى
# 222                 Hotel Pamplona Plaza
# 234                        Hôtel Madania
# 247                        Hotel Cristal
# 260                          فندق الأمان
# 276             Wasserturm Hotel Cologne
# 299                         Queens Hotel
# 309    مرکز آموزشی رفاهی فرهنگیان بجنورد
# 317                           Miymanxana
# 364                       No hotel found
# 386                                 Хами
# 398                             Andalous
# 418                    Dolphin Bay Hotel
# 439               La Quinta Inn & Suites
# 454                   Kona Seaside Hotel
# 556              Protea Hotel Mossel Bay
# 569                  Le Méridien Qingdao

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotels_found = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 900,
    frame_height = 700,
    size = "Humidity",
    color="City",
    alpha=.70,
    hover_cols=["Hotel Name", "Country"]
).opts(title="Hotels within 10,000 meters of city")

# Display the map
hotels_found
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
